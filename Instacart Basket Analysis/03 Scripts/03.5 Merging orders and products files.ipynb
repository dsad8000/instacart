# %% [markdown]
# # 03.5 Merging orders and products files
# ### This script contains the following points
# #### 1. Import the saved dataframe from saved pkl file.
# #### 2. Check imported dataframe.
# #### 3. Merge dataframe with products data set.
# #### 4. Confirm the results using merge flag.

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1. Import the saved dataframe from saved pkl file.

# %%
# Import csv and pkl files
path = r'C:\Users\dsadl\OneDrive\Documents\Career Foundry\Data Immersion\Project 4\05-10-2023 Instacart Basket Analysis'

# %%
df_prods= pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_ord_prod_comb=pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# #### 2. Check imported dataframe.

# %%
# Check the output
df_ord_prod_comb.shape
# Out:
# (32434489, 11)

# %%
df_ord_prod_comb.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Drop "Unnamed: 0" columns
df_prods.drop(columns = 'Unnamed: 0')
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_ord_prod_comb.drop(columns=['Unnamed: 0'])
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0          2539329        1             1                   2           8
# 1          2539329        1             1                   2           8
# 2          2539329        1             1                   2           8
# 3          2539329        1             1                   2           8
# 4          2539329        1             1                   2           8
# ...            ...      ...           ...                 ...         ...
# 32434484   2977660   206209            13                   1          12
# 32434485   2977660   206209            13                   1          12
# 32434486   2977660   206209            13                   1          12
# 32434487   2977660   206209            13                   1          12
# 32434488   2977660   206209            13                   1          12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# #### 3. Merge dataframe with products data set.

# %%
# Merge imported combined dataframe with products data set
df_merged = df_ord_prod_comb.merge(df_prods, on = ('product_id'))

# %%
df_merged
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0                    0   2539329        1             1                   2
# 1                    1   2398795        1             2                   3
# 2                    2    473747        1             3                   3
# 3                    3   2254736        1             4                   4
# 4                    4    431534        1             5                   4
# ...                ...       ...      ...           ...                 ...
# 32404854       3360493   1320836   202557            17                   2
# 32404855       3360494     31526   202557            18                   5
# 32404856       3376038    758936   203436             1                   2
# 32404857       3376039   2745165   203436             2                   3
# 32404858       3408036   3093936   205420             1                   4
#
# ...

# %% [markdown]
# #### 4. Confirm the results using merge flag.

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Dropping "Unnamed: 0" columns again
df_merged.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0_y'])
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0          2539329        1             1                   2           8
# 1          2398795        1             2                   3           7
# 2           473747        1             3                   3          12
# 3          2254736        1             4                   4           7
# 4           431534        1             5                   4          15
# ...            ...      ...           ...                 ...         ...
# 32404854   1320836   202557            17                   2          15
# 32404855     31526   202557            18                   5          11
# 32404856    758936   203436             1                   2           7
# 32404857   2745165   203436             2                   3           5
# 32404858   3093936   205420             1                   4          14
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
# Exporting as pkl file
df_merged.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged.pkl'))
